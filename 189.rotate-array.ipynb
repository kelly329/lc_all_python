# %% [markdown]
# ### [LeetCode]题解（Python）：189- Rotate Array

# %% [markdown]
# ### 题目来源：
# https://leetcode.com/problems/rotate-array/

# %% [markdown]
# ### 题意分析：
# 旋转数组，给定数组长度n，旋转位移k，将数组元素循环右移k位。

# %% [markdown]
# ### 解题思路
# - 将数组从k位置分为前后两半；
# - 翻转前半部分；
# - 翻转后半部分；
# - 翻转整个数组；
# ![20150423153635427.png](attachment:20150423153635427.png)

# %% [markdown]
# ### 代码Python：

# %%
class Solution(object):
    def rotate(self, nums, k):
        """
        :type nums: List[int]
        :type k: int
        :rtype: void Do not return anything, modify nums in-place instead.
        """
        if len(nums) == 0 or k == 0:
            return
        def reverse(start, end, s):
            s[start], s[end] = s[end], s[start]
            start += 1
            end -= 1
        
        n = len(nums) - 1
        k = k % len(nums)
        # 右移 所以剩余右边
        reverse(0, n - k, nums)
        reverse(n - k + 1, n, nums)
        reverse(0, n, nums)
